# %% [markdown]
# # <center> Cleaning and Examining Ebay Car Sales Data </center>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# The aim of this project is to clean the data and analyze the included used car listings.
#
# This is the data dictionary provided with data:
#
# - `dateCrawled` - When this ad was first crawled. All field-values are taken from this date.
# - `name` - Name of the car.
# - `seller` - Whether the seller is private or a dealer.
# - `offerType` - The type of listing
# - `price` - The price on the ad to sell the car.
# - `abtest` - Whether the listing is included in an A/B test.
# - `vehicleType` - The vehicle Type.
# - `yearOfRegistration` - The year in which the car was first registered.
# - `gearbox` - The transmission type.
# - `powerPS` - The power of the car in PS.
# - `model` - The car model name.
# - `kilometer` - How many kilometers the car has driven.
# - `monthOfRegistration` - The month in which the car was first registered.
# - `fuelType` - What type of fuel the car uses.
# - `brand` - The brand of the car.
# - `notRepairedDamage`- If the car has a damage which is not yet repaired.
# - `dateCreated` - The date on which the eBay listing was created.
# - `nrOfPictures` - The number of pictures in the ad.
# - `postalCode` - The postal code for the location of the vehicle.
# - `lastSeenOnline` - When the crawler saw this ad last online.

# %% [markdown]
# ## 2. Importing modules, reading the csv and first looks at the data
# Reading the csv with the right encoding (default:UTF-8) or (Latin-1 and Windows-1252)

# %%
import pandas as pd
import numpy as np

autos = pd.read_csv("autos.csv", encoding="Latin-1")
#print(autos.head())

# %% [markdown]
# Autoformating of jupyter of a variable

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# ## 3. Cleaning the headers of the columns
# Cleanup some of the column headers. Snakecase instead of camel case and make it easier to understand.

# %%
new_column_names = autos
#print("Before column header change:")
#print(new_column_names.columns)
new_column_names.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
new_column_names.columns = new_column_names.columns.str.replace("yearOfRegistration", "registration_year")
new_column_names.columns = new_column_names.columns.str.replace("monthOfRegistration", "registration_month")
new_column_names.columns = new_column_names.columns.str.replace("notRepairedDamage", "unrepaired_damage")
new_column_names.columns = new_column_names.columns.str.replace("dateCreated", "ad_created")
new_column_names.columns = new_column_names.columns.str.replace("vehicleType", "vehicle_type")
new_column_names.columns = new_column_names.columns.str.replace("offerType", "offer_type")
new_column_names.columns = new_column_names.columns.str.replace("lastSeen", "last_seen")
new_column_names.columns = new_column_names.columns.str.replace("dateCrawled", "date_crawled")
new_column_names.columns = new_column_names.columns.str.replace("postalCode", "post_code")
new_column_names.columns = new_column_names.columns.str.replace("nrOfPictures", "num_pictures")
new_column_names.columns = new_column_names.columns.str.lower()
new_column_names.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'powerps', 'model',
#        'odometer', 'registration_month', 'fueltype', 'brand',
#        'unrepaired_damage', 'ad_created', 'num_pictures', 'post_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.columns = new_column_names.columns
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  powerps   model   odometer  registration_month fueltype  \
# ...

# %% [markdown]
# ## 4. Cleaning up individual columns
# Looking at the data more closely.
# Results from looking at the data:
# The seller column appears to have the same entry 49,999 of 50,000 says "private". Perhaps drop this column?
# Registration Year could be cleaned up. Strange entries.
# Odometer column needs text removed and made to an integer.

# %%
autos.describe(include="all")
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-23 18:39:34  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox       powerps  model  \
# ...

# %% [markdown]
# To cleanup the Price column

# %%
autos['price'] = (autos['price']
                            .str.replace("$", "")
                            .str.replace(",", "")
                            .astype(int))
# Out:
# <ipython-input-9-1d4e92c71fe4>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   autos['price'] = (autos['price']

# %% [markdown]
# To cleanup the odometer column

# %%
autos.rename({"odometer": "odometer_km"}, axis=1, inplace=True)

autos['odometer_km'] = (autos['odometer_km']
                            .str.replace("km", "")
                            .str.replace(",", "")
                            .astype(int))
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %% [markdown]
# ## 5. Examining the odometer_km and price columns in detail
# Examining the odometer_km and price columns more closely for outliners.

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date_crawled        50000 non-null  object
#  1   name                50000 non-null  object
#  2   seller              50000 non-null  object
#  3   offer_type          50000 non-null  object
#  4   price               50000 non-null  int32
#  5   abtest              50000 non-null  object
#  6   vehicle_type        44905 non-null  object
#  7   registration_year   50000 non-null  int64
#  8   gearbox             47320 non-null  object
#  9   powerps             50000 non-null  int64
#  10  model               47242 non-null  object
#  11  odometer_km         50000 non-null  int32
#  12  registration_month  50000 non-null  int64
#  13  fueltype            45518 non-null  object
#  14  brand               50000 non-null  object
# ...

# %% [markdown]
# ### Examining the Price column

# %%
autos["price"].unique().shape
# Out:
# (2357,)

# %% [markdown]
# There are 2357 unique entries for the prices and 13 for odometer

# %%
autos["price"].describe().round()
# Out:
# count       50000.0
# mean         9840.0
# std        481104.0
# min             0.0
# 25%          1100.0
# 50%          2950.0
# 75%          7200.0
# max      99999999.0
# Name: price, dtype: float64

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot   5000  control          bus               2004
# 1  privat    Angebot   8500  control    limousine               1997
# 2  privat    Angebot   8990     test    limousine               2009
# 3  privat    Angebot   4350  control   kleinwagen               2007
# 4  privat    Angebot   1350     test        kombi               2003
#
#      gearbox  powerps   model  odometer_km  registration_month fueltype  \
# ...

# %%
autos['price'].value_counts().sort_index(ascending = False)
# Out:
# 99999999       1
# 27322222       1
# 12345678       3
# 11111111       2
# 10000000       1
#             ...
# 5              2
# 3              1
# 2              3
# 1            156
# 0           1421
# Name: price, Length: 2357, dtype: int64

# %% [markdown]
# #### Lets make a separate list of all the cars above $100,000 so that we can catch the index number of overpriced and unrealistic car prices

# %%
Top_priced = autos[(autos["price"] >= 100000) ].sort_index(ascending = False)

# %%
Top_priced = Top_priced[["price","name","vehicle_type","model"]]

# %%
Top_priced
# Out:
#           price                                               name  \
# 49815    130000  SUCHE_TIPPS___Ford_Mustang_Shelby_GT_350_500_K...
# 49668    145000         Porsche_911__993__Carrera_S_"SONDERMODELL"
# 49391    109999  Lamborghini_Gallardo_LP560_4_E_Gear_"Callisto_...
# 47634   3890000                                        Ferrari_FXX
# 47598  12345678  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...
# 47337    259000                                    BMW_Z8_roadster
# 45387    163500  Porsche_911_GT3__Clubsp._Lift_nur_bis_25.03._v...
# 44406    120000  Mercedes_Benz_170_S_Cabriolet_A__Startklar_fue...
# 43668    197000  Porsche_993/911_Turbo_WLS_II_Exclusive_S_deuts...
# 43282    119900               Porsche_911_Carrera_4S_Cabriolet_PDK
# 43049    999999                                      2_VW_Busse_T3
# 42221  27322222                                  Leasinguebernahme
# 40918    198000                             Porsche_911_991_GT3_RS
# ...

# %% [markdown]
# #### Lets delete entries with values of 12345678, 99999999, 11111111, 999999 by first making a list

# %%
bad_entries_prices = [12345678, 99999999, 11111111, 999999]

# %% [markdown]
# Lets check the Citroens as well

# %%
citroens = autos[(autos["brand"] == "citroen")]
citroens = citroens.sort_values(by=["price"], ascending=False)
citroens.head()
# Out:
#               date_crawled                                               name  \
# 42221  2016-03-08 20:39:05                                  Leasinguebernahme
# 48944  2016-03-21 15:43:49            Citroën_C2_1.6_16V_Senso_Drive_VTR_Plus
# 6476   2016-03-29 18:46:08  Citroen_DS20_Pallas_1973_Halbautomatik_/_wenig...
# 21720  2016-03-30 20:58:36       Citroën_C5_Tourer_HDi_200_FAP_Aut._Exclusive
# 11315  2016-04-01 17:57:47      Roadster__2CV6__Unikat__Karosserie_kompl._Alu
#
#        seller offer_type     price   abtest vehicle_type  registration_year  \
# 42221  privat    Angebot  27322222  control    limousine               2014
# 48944  privat    Angebot     33000  control   kleinwagen               2005
# 6476   privat    Angebot     25000  control          NaN               1973
# 21720  privat    Angebot     22900  control        kombi               2013
# 11315  privat    Angebot     21111     test       cabrio               1986
#
# ...

# %%
sonstige_autos = autos[(autos["brand"] == "sonstige_autos")]
sonstige_autos = sonstige_autos.sort_values(by=["price"], ascending=False)
sonstige_autos.head()
# Out:
#               date_crawled                                               name  \
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 47634  2016-04-04 21:25:21                                        Ferrari_FXX
# 7814   2016-04-04 11:53:31                                        Ferrari_F40
# 14715  2016-03-30 08:37:24                 Rolls_Royce_Phantom_Drophead_Coupe
# 28090  2016-03-08 19:50:06  Tesla_Model_X_P90D_Signature_Sondermodel__Neuw...
#
#        seller offer_type     price   abtest vehicle_type  registration_year  \
# 11137  privat    Angebot  10000000  control        coupe               1960
# 47634  privat    Angebot   3890000     test        coupe               2006
# 7814   privat    Angebot   1300000  control        coupe               1992
# 14715  privat    Angebot    345000  control       cabrio               2012
# 28090  privat    Angebot    194000     test          suv               2016
#
# ...

# %% [markdown]
# #### Making a boolean list of these so that I can extract the

# %%
bad_bool = ((autos["price"] == 12345678) | (autos["price"] == 99999999) | (autos["price"] == 11111111) | (autos["price"] == 999999) | (autos["price"] == 1234566) | (autos["price"] == 27322222) | (autos["price"] == 10000000))

# %% [markdown]
# #### The list of bad entries so far

# %%
bad_entries = autos[bad_bool]
bad_entries
# Out:
#               date_crawled                                               name  \
# 514    2016-03-17 09:53:08                   Ford_Focus_Turnier_1.6_16V_Style
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 22947  2016-03-22 12:54:19                         Bmw_530d_zum_ausschlachten
# 24384  2016-03-21 13:57:51                            Schlachte_Golf_3_gt_tdi
# 27371  2016-03-09 15:45:47                                         Fiat_Punto
# 39377  2016-03-08 23:53:51                        Tausche_volvo_v40_gegen_van
# 39705  2016-03-22 14:58:27                        Tausch_gegen_gleichwertiges
# 42221  2016-03-08 20:39:05                                  Leasinguebernahme
# 43049  2016-03-21 19:53:52                                      2_VW_Busse_T3
# 47598  2016-03-31 18:56:54  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...
#
# ...

# %% [markdown]
# #### To remove the bad entries from the autos list

# %%
for remove in bad_entries.index:
    autos.drop([remove], inplace = True)

# %% [markdown]
# #### The statistics for the price column looks  much better now

# %%
autos["price"].describe().round()
# Out:
# count      49989.0
# mean        5845.0
# std        20876.0
# min            0.0
# 25%         1100.0
# 50%         2950.0
# 75%         7200.0
# max      3890000.0
# Name: price, dtype: float64

# %% [markdown]
# #### To look at the lowest values next that are priced under 10 dollars:

# %%
cheaply_priced = autos[(autos["price"] <= 10)].sort_index(ascending = False)
cheaply_priced
# Out:
#               date_crawled                                               name  \
# 49984  2016-03-31 22:48:48  Student_sucht_ein__Anfaengerauto___ab_2000_BJ_...
# 49974  2016-03-20 10:52:31  Golf_1_Cabrio_Tuev_Neu_viele_Extras_alles_eing...
# 49960  2016-03-25 22:51:55            Ford_KA_zu_verschenken_***Reserviert***
# 49943  2016-03-16 20:46:08                                         Opel_astra
# 49884  2016-03-11 13:55:30               Audi_a6_2.5l__Schnaeppchen_nur_heute
# ...                    ...                                                ...
# 87     2016-03-29 23:37:22                      Bmw_520_e39_zum_ausschlachten
# 80     2016-03-09 15:57:57  Nissan_Primera_Hatchback_1_6_16v_73_Kw___99Ps_...
# 71     2016-03-28 19:39:35  Suche_Opel_Astra_F__Corsa_oder_Kadett_E_mit_Re...
# 55     2016-03-07 02:47:54                     Mercedes_E320_AMG_zu_Tauschen!
# 27     2016-03-27 18:45:01             Hat_einer_Ahnung_mit_Ford_Galaxy_HILFE
#
# ...

# %% [markdown]
# #### Lets investigate all of the cars priced at 0
# How many of them are there?

# %%
tot_num_cars = len(autos)

# %%
free_num_cars = len(autos[autos["price"] == 0])

# %%
print("There are " + str(free_num_cars) + " cars priced at zero of a total " + str(tot_num_cars) + " cars.")
# Out:
# There are 1421 cars priced at zero of a total 49989 cars.

# %%
print(str("{:.2f}".format(free_num_cars / tot_num_cars * 100)) + " % of total car sales are set as free")
# Out:
# 2.84 % of total car sales are set as free

# %% [markdown]
# Since investigating this, perhaps we should leave them for sellers may want to just have their cars removed from them for free

# %% [markdown]
# ### Examining the Odometer column

# %%
autos['odometer_km'].describe()
# Out:
# count     49989.000000
# mean     125733.061273
# std       40042.153403
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
unique_values = autos["odometer_km"].unique()
np.sort(unique_values)
# Out:
# array([  5000,  10000,  20000,  30000,  40000,  50000,  60000,  70000,
#         80000,  90000, 100000, 125000, 150000])

# %% [markdown]
# All of these values look reasonable

# %% [markdown]
# ### How many null values are there in each of the subheadings?

# %%
autos.isnull().sum()
# Out:
# date_crawled             0
# name                     0
# seller                   0
# offer_type               0
# price                    0
# abtest                   0
# vehicle_type          5092
# registration_year        0
# gearbox               2678
# powerps                  0
# model                 2755
# odometer_km              0
# registration_month       0
# fueltype              4479
# brand                    0
# unrepaired_damage     9823
# ad_created               0
# num_pictures             0
# post_code                0
# last_seen                0
# dtype: int64

# %% [markdown]
# This provides an overview of what columns hold information and might be valuable in assessing car sales. It seems that vehicletype, gearbox, model, fueltype and unrepaired damage to be lacking information,

# %% [markdown]
# ## 6. Cleaning up the dates

# %% [markdown]
# Here I will concentrate on columns: "date_crawled", "last_seen", "ad_created", "registration_month", "registration_year"
# There are columns as strings and need to be converted to numerical representation.

# %%
autos.iloc[0]
# Out:
# date_crawled                       2016-03-26 17:47:46
# name                  Peugeot_807_160_NAVTECH_ON_BOARD
# seller                                          privat
# offer_type                                     Angebot
# price                                             5000
# abtest                                         control
# vehicle_type                                       bus
# registration_year                                 2004
# gearbox                                        manuell
# powerps                                            158
# model                                           andere
# odometer_km                                     150000
# registration_month                                   3
# fueltype                                           lpg
# brand                                          peugeot
# unrepaired_damage                                 nein
# ad_created                         2016-03-26 00:00:00
# ...

# %%
date_col = ["date_crawled", "last_seen", "ad_created"]
for col in date_col:
    autos[col] = autos[col].str[:10]

# %% [markdown]
# The dates have now been shortened so that the times are not present

# %%
autos.head()
# Out:
#   date_crawled                                               name  seller  \
# 0   2016-03-26                   Peugeot_807_160_NAVTECH_ON_BOARD  privat
# 1   2016-04-04         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
# 2   2016-03-26                         Volkswagen_Golf_1.6_United  privat
# 3   2016-03-12  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...  privat
# 4   2016-04-01  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...  privat
#
#   offer_type  price   abtest vehicle_type  registration_year    gearbox  \
# 0    Angebot   5000  control          bus               2004    manuell
# 1    Angebot   8500  control    limousine               1997  automatik
# 2    Angebot   8990     test    limousine               2009    manuell
# 3    Angebot   4350  control   kleinwagen               2007  automatik
# 4    Angebot   1350     test        kombi               2003    manuell
#
#    powerps   model  odometer_km  registration_month fueltype       brand  \
# ...

# %%
for item in date_col:
    autos[item] = pd.to_datetime(autos[item], format="%Y-%m-%d")

# %% [markdown]
# Yes. It is now a recognisable numerical value for calculations

# %%
autos.loc[0, "date_crawled"]
# Out:
# Timestamp('2016-03-26 00:00:00')

# %%
autos.loc[0, "date_crawled"].day_name()
# Out:
# 'Saturday'

# %%
autos.loc[0, "last_seen"].day_name()
# Out:
# 'Wednesday'

# %% [markdown]
# To look at just the top 5 rows of the interested headings:

# %%
dates = autos[["date_crawled", "last_seen", "ad_created", "registration_month", "registration_year"]]
dates.head()
# Out:
#   date_crawled  last_seen ad_created  registration_month  registration_year
# 0   2016-03-26 2016-04-06 2016-03-26                   3               2004
# 1   2016-04-04 2016-04-06 2016-04-04                   6               1997
# 2   2016-03-26 2016-04-06 2016-03-26                   7               2009
# 3   2016-03-12 2016-03-15 2016-03-12                   6               2007
# 4   2016-04-01 2016-04-01 2016-04-01                   7               2003

# %% [markdown]
# The dtype is now datetime64

# %%
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49989 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date_crawled        49989 non-null  datetime64[ns]
#  1   last_seen           49989 non-null  datetime64[ns]
#  2   ad_created          49989 non-null  datetime64[ns]
#  3   registration_month  49989 non-null  int64
#  4   registration_year   49989 non-null  int64
# dtypes: datetime64[ns](3), int64(2)
# memory usage: 3.3 MB

# %% [markdown]
# What is the oldest and newest advertisement?

# %%
autos["ad_created"].min()
# Out:
# Timestamp('2015-06-11 00:00:00')

# %%
autos["ad_created"].max()
# Out:
# Timestamp('2016-04-07 00:00:00')

# %% [markdown]
# The oldest entry is from 2015 and the oldest is 2016

# %% [markdown]
# To order the entries by newest at the top to oldest at the bottom, use:

# %%
autos = autos.sort_values(by=["ad_created"], ascending=False)

# %% [markdown]
# Lets look closer at the registration year

# %%
autos["registration_year"].describe()
# Out:
# count    49989.000000
# mean      2005.075077
# std        105.724042
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# There are false values of 9999 to be removed. Lets see these entries.
# Perhaps a more efficient approach is to select everything that is in the future of the current year which is 2021

# %%
bad_bool_list = (autos["registration_year"] >= 2021) | (autos["registration_year"] <= 1801)
bad_list = autos[bad_bool_list]
# print(autos["registration_year"] == 9999)
bad_list
# Out:
#       date_crawled                                               name  seller  \
# 38076   2016-04-04                                 Mercedes_Benz_A180  privat
# 49910   2016-04-03  Schoener_fast_neuer_Opel_Mokka_in_Zell_Mosel_m...  privat
# 32585   2016-04-02                                         UNFAL_Auto  privat
# 10556   2016-04-01                                         UNFAL_Auto  privat
# 4549    2016-04-01                                         Kompressor  privat
# 27578   2016-03-31                                   VW_GOLF_2_SYNCRO  privat
# 22316   2016-03-29              VW_Kaefer.__Zwei_zum_Preis_von_einem.  privat
# 27618   2016-03-29  Golf_1_75ps_5911km_Original_Automatik_einer_de...  privat
# 4164    2016-03-29  Verkaufe_DESIGN_Streifen_/_Aufkleber_VW__Opel_...  privat
# 453     2016-03-28                                         Armee_Jeep  privat
# 35238   2016-03-26   Suche_Skoda_Fabia____Skoda_Fabia_Combi_mit_Klima  privat
# ...

# %%
for remove in bad_list.index:
    autos.drop([remove], inplace = True)

# %% [markdown]
# Just to check that these values have been removed

# %%
autos = autos.sort_values(by=["registration_year"], ascending=False)
autos.head()
# Out:
#       date_crawled                                              name  seller  \
# 5763    2016-03-05            Suche_Auspuff_Anlage_honda_crx_del_sol  privat
# 38342   2016-03-07             Suche_Auto_fuer_die_jagd_zum_tauschen  privat
# 49185   2016-03-28             Alfa_Romeo_156_Sportwagon_1_8_T_Spark  privat
# 49262   2016-03-26                                       Opel_vectra  privat
# 8882    2016-03-15  Volvo_C30_1.6D_130294km__TÜV_bis_02.2018___Leder  privat
#
#       offer_type  price   abtest vehicle_type  registration_year  gearbox  \
# 5763     Angebot    100     test          NaN               2019  manuell
# 38342    Angebot      0  control          NaN               2019      NaN
# 49185    Angebot   1200  control          NaN               2019  manuell
# 49262    Angebot   2000     test          NaN               2018      NaN
# 8882     Angebot   5300  control          NaN               2018  manuell
#
# ...

# %% [markdown]
# Now the following statistics make more sense

# %%
autos["registration_year"].describe()
# Out:
# count    49965.000000
# mean      2003.368258
# std          7.689636
# min       1910.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2019.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# ## 7. Aggregating data to view the brand column

# %%
autos["brand"].unique()
# Out:
# array(['honda', 'sonstige_autos', 'alfa_romeo', 'opel', 'volvo',
#        'mercedes_benz', 'renault', 'ford', 'suzuki', 'volkswagen',
#        'peugeot', 'seat', 'audi', 'fiat', 'bmw', 'mazda', 'mitsubishi',
#        'toyota', 'lada', 'citroen', 'hyundai', 'smart', 'daihatsu',
#        'lancia', 'dacia', 'kia', 'nissan', 'skoda', 'daewoo', 'chevrolet',
#        'subaru', 'saab', 'jaguar', 'porsche', 'mini', 'land_rover',
#        'trabant', 'chrysler', 'rover', 'jeep'], dtype=object)

# %%
len(autos["brand"].unique())
# Out:
# 40

# %% [markdown]
# There are 40 different brands available as listed above.
# What is the most expensive price for each brand?
# What are top 10 most expensive brands?

# %%
expensive_price_each_brand = {}

brands = autos["brand"].unique()
for each in brands:
    selected_rows = autos[autos["brand"] == each]
    sorted_rows = selected_rows.sort_values("price", ascending=False)
    first_row = sorted_rows.iloc[0]
    price = first_row["price"]
    expensive_price_each_brand[each] = price

# %%
expensive_price_each_brand
# Out:
# {'honda': 41900,
#  'sonstige_autos': 3890000,
#  'alfa_romeo': 55000,
#  'opel': 38990,
#  'volvo': 29500,
#  'mercedes_benz': 180000,
#  'renault': 93000,
#  'ford': 130000,
#  'suzuki': 23200,
#  'volkswagen': 999990,
#  'peugeot': 25500,
#  'seat': 33500,
#  'audi': 175000,
#  'fiat': 25000,
#  'bmw': 259000,
#  'mazda': 38900,
#  'mitsubishi': 37800,
#  'toyota': 49500,
#  'lada': 6500,
#  'citroen': 33000,
#  'hyundai': 29999,
#  'smart': 16850,
#  'daihatsu': 9900,
#  'lancia': 29500,
#  'dacia': 16350,
#  'kia': 28450,
#  'nissan': 34999,
#  'skoda': 32700,
#  'daewoo': 4200,
#  'chevrolet': 56500,
#  'subaru': 31800,
#  'saab': 18900,
#  'jaguar': 58900,
#  'porsche': 350000,
#  'mini': 34500,
#  'land_rover': 99000,
#  'trabant': 6480,
#  'chrysler': 20000,
#  'rover': 23500,
#  'jeep': 55800}

# %% [markdown]
# Now to put it into a descending order:

# %%
sorted_list = dict(sorted(expensive_price_each_brand.items(), key=lambda item: item[1], reverse=True))
sorted_list
# Out:
# {'sonstige_autos': 3890000,
#  'volkswagen': 999990,
#  'porsche': 350000,
#  'bmw': 259000,
#  'mercedes_benz': 180000,
#  'audi': 175000,
#  'ford': 130000,
#  'land_rover': 99000,
#  'renault': 93000,
#  'jaguar': 58900,
#  'chevrolet': 56500,
#  'jeep': 55800,
#  'alfa_romeo': 55000,
#  'toyota': 49500,
#  'honda': 41900,
#  'opel': 38990,
#  'mazda': 38900,
#  'mitsubishi': 37800,
#  'nissan': 34999,
#  'mini': 34500,
#  'seat': 33500,
#  'citroen': 33000,
#  'skoda': 32700,
#  'subaru': 31800,
#  'hyundai': 29999,
#  'volvo': 29500,
#  'lancia': 29500,
#  'kia': 28450,
#  'peugeot': 25500,
#  'fiat': 25000,
#  'rover': 23500,
#  'suzuki': 23200,
#  'chrysler': 20000,
#  'saab': 18900,
#  'smart': 16850,
#  'dacia': 16350,
#  'daihatsu': 9900,
#  'lada': 6500,
#  'trabant': 6480,
#  'daewoo': 4200}

# %%
top_10 = list(sorted_list.items())[:10]
top_10
# Out:
# [('sonstige_autos', 3890000),
#  ('volkswagen', 999990),
#  ('porsche', 350000),
#  ('bmw', 259000),
#  ('mercedes_benz', 180000),
#  ('audi', 175000),
#  ('ford', 130000),
#  ('land_rover', 99000),
#  ('renault', 93000),
#  ('jaguar', 58900)]

# %% [markdown]
# What is the mean price for each brand?

# %%
mean_price = {}

brands = autos["brand"].unique()
for each in brands:
    selected_rows = autos[autos["brand"] == each]
    average_values = selected_rows["price"].mean()
    mean_price[each] = average_values
    
mean_price
# Out:
# {'honda': 3889.8596491228072,
#  'sonstige_autos': 20154.637707948244,
#  'alfa_romeo': 3943.562310030395,
#  'opel': 2842.8246289169874,
#  'volvo': 4685.548245614035,
#  'mercedes_benz': 8380.637920101459,
#  'renault': 2351.301996672213,
#  'ford': 3626.5429968363533,
#  'suzuki': 4038.952218430034,
#  'volkswagen': 5252.550561797752,
#  'peugeot': 3010.8688186813188,
#  'seat': 4223.654255319149,
#  'audi': 8965.560354891431,
#  'fiat': 2697.6771231828616,
#  'bmw': 8028.474479454579,
#  'mazda': 3962.542932628798,
#  'mitsubishi': 3328.227722772277,
#  'toyota': 5097.941653160454,
#  'lada': 2476.9032258064517,
#  'citroen': 3680.8440629470674,
#  'hyundai': 5316.754098360656,
#  'smart': 3482.971469329529,
#  'daihatsu': 1552.09375,
#  'lancia': 3070.3508771929824,
#  'dacia': 5897.736434108527,
#  'kia': 5707.3258426966295,
#  'nissan': 4588.879310344828,
#  'skoda': 6313.076433121019,
#  'daewoo': 1038.3544303797469,
#  'chevrolet': 6432.929328621908,
# ...

# %%
sorted_mean_list = dict(sorted(expensive_price_each_brand.items(), key=lambda item: item[1], reverse=True))
sorted_mean_list
# Out:
# {'sonstige_autos': 3890000,
#  'volkswagen': 999990,
#  'porsche': 350000,
#  'bmw': 259000,
#  'mercedes_benz': 180000,
#  'audi': 175000,
#  'ford': 130000,
#  'land_rover': 99000,
#  'renault': 93000,
#  'jaguar': 58900,
#  'chevrolet': 56500,
#  'jeep': 55800,
#  'alfa_romeo': 55000,
#  'toyota': 49500,
#  'honda': 41900,
#  'opel': 38990,
#  'mazda': 38900,
#  'mitsubishi': 37800,
#  'nissan': 34999,
#  'mini': 34500,
#  'seat': 33500,
#  'citroen': 33000,
#  'skoda': 32700,
#  'subaru': 31800,
#  'hyundai': 29999,
#  'volvo': 29500,
#  'lancia': 29500,
#  'kia': 28450,
#  'peugeot': 25500,
#  'fiat': 25000,
#  'rover': 23500,
#  'suzuki': 23200,
#  'chrysler': 20000,
#  'saab': 18900,
#  'smart': 16850,
#  'dacia': 16350,
#  'daihatsu': 9900,
#  'lada': 6500,
#  'trabant': 6480,
#  'daewoo': 4200}

# %% [markdown]
# What is the average km?

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'powerps', 'model',
#        'odometer_km', 'registration_month', 'fueltype', 'brand',
#        'unrepaired_damage', 'ad_created', 'num_pictures', 'post_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# Lets use the column heading "odometer_km" for the avergae and sort by descending order

# %%
mean_km = {}

brands = autos["brand"].unique()
for each in brands:
    selected_rows = autos[autos["brand"] == each]
    average_values = selected_rows["odometer_km"].mean()
    mean_km[each] = round(average_values)

mean_km = dict(sorted(mean_km.items(), key=lambda item: item[1], reverse=True))
mean_km
# Out:
# {'saab': 143671,
#  'volvo': 138607,
#  'rover': 136449,
#  'chrysler': 133149,
#  'bmw': 132541,
#  'alfa_romeo': 131109,
#  'mercedes_benz': 130933,
#  'audi': 129644,
#  'opel': 129361,
#  'volkswagen': 129008,
#  'renault': 128224,
#  'jeep': 127523,
#  'peugeot': 127352,
#  'mitsubishi': 126894,
#  'subaru': 125556,
#  'mazda': 125132,
#  'ford': 124153,
#  'honda': 123709,
#  'lancia': 123158,
#  'seat': 122186,
#  'daewoo': 121709,
#  'jaguar': 121299,
#  'citroen': 120043,
#  'nissan': 118979,
#  'land_rover': 118333,
#  'fiat': 117012,
#  'toyota': 115989,
#  'daihatsu': 114844,
#  'kia': 112640,
#  'skoda': 111083,
#  'suzuki': 109334,
#  'hyundai': 106783,
#  'smart': 100756,
#  'chevrolet': 99523,
#  'porsche': 97364,
#  'mini': 89375,
#  'sonstige_autos': 87754,
#  'lada': 86774,
#  'dacia': 84729,
#  'trabant': 60065}

# %% [markdown]
# Lets make this a series

# %%
bmp_series = pd.Series(sorted_mean_list)

# %%
bmp_series
# Out:
# sonstige_autos    3890000
# volkswagen         999990
# porsche            350000
# bmw                259000
# mercedes_benz      180000
# audi               175000
# ford               130000
# land_rover          99000
# renault             93000
# jaguar              58900
# chevrolet           56500
# jeep                55800
# alfa_romeo          55000
# toyota              49500
# honda               41900
# opel                38990
# mazda               38900
# mitsubishi          37800
# nissan              34999
# mini                34500
# seat                33500
# citroen             33000
# skoda               32700
# subaru              31800
# hyundai             29999
# volvo               29500
# lancia              29500
# kia                 28450
# peugeot             25500
# fiat                25000
# rover               23500
# suzuki              23200
# chrysler            20000
# saab                18900
# smart               16850
# ...

# %% [markdown]
# Lets make this a DataFrame

# %%
new_df = pd.DataFrame(bmp_series, columns=["mean_price"])
new_df.head()
# Out:
#                 mean_price
# sonstige_autos     3890000
# volkswagen          999990
# porsche             350000
# bmw                 259000
# mercedes_benz       180000

# %% [markdown]
# Now to add the column of average kms

# %%
bmp_series = pd.Series(mean_km)
bmp_series.head()
# Out:
# saab        143671
# volvo       138607
# rover       136449
# chrysler    133149
# bmw         132541
# dtype: int64

# %%
new_df["mean_km"] = bmp_series
new_df.head()
# Out:
#                 mean_price  mean_km
# sonstige_autos     3890000    87754
# volkswagen          999990   129008
# porsche             350000    97364
# bmw                 259000   132541
# mercedes_benz       180000   130933

# %% [markdown]
# In Summary, this table shows that the mean price and the mean km are not directly proportional even though some think that the less you drive a car, the more its value. Perhaps this is still the case for some calssics though.

# %% [markdown]
# ## 8. Converting German words to English ones

# %%
autos.head()
# Out:
#       date_crawled                                              name  seller  \
# 5763    2016-03-05            Suche_Auspuff_Anlage_honda_crx_del_sol  privat
# 38342   2016-03-07             Suche_Auto_fuer_die_jagd_zum_tauschen  privat
# 49185   2016-03-28             Alfa_Romeo_156_Sportwagon_1_8_T_Spark  privat
# 49262   2016-03-26                                       Opel_vectra  privat
# 8882    2016-03-15  Volvo_C30_1.6D_130294km__TÜV_bis_02.2018___Leder  privat
#
#       offer_type  price   abtest vehicle_type  registration_year  gearbox  \
# 5763     Angebot    100     test          NaN               2019  manuell
# 38342    Angebot      0  control          NaN               2019      NaN
# 49185    Angebot   1200  control          NaN               2019  manuell
# 49262    Angebot   2000     test          NaN               2018      NaN
# 8882     Angebot   5300  control          NaN               2018  manuell
#
# ...

# %% [markdown]
# Lets change "unrepaired_damage" from nein to "no damage"
# Lets also change the np.nan to "no damage" as well
# Lets also change the response to the offer type from "Angebot" to "offer"
# Also, the seller from "privat" to "private"

# %%
autos["unrepaired_damage"] = autos["unrepaired_damage"].replace("nein", "no damage")
autos["unrepaired_damage"] = autos["unrepaired_damage"].replace(np.nan, "no damage")
autos["offer_type"] = autos["offer_type"].replace("Angebot", "offer")
autos["seller"] = autos["seller"].replace("privat", "private")
autos.head()
# Out:
#       date_crawled                                              name   seller  \
# 5763    2016-03-05            Suche_Auspuff_Anlage_honda_crx_del_sol  private
# 38342   2016-03-07             Suche_Auto_fuer_die_jagd_zum_tauschen  private
# 49185   2016-03-28             Alfa_Romeo_156_Sportwagon_1_8_T_Spark  private
# 49262   2016-03-26                                       Opel_vectra  private
# 8882    2016-03-15  Volvo_C30_1.6D_130294km__TÜV_bis_02.2018___Leder  private
#
#       offer_type  price   abtest vehicle_type  registration_year  gearbox  \
# 5763       offer    100     test          NaN               2019  manuell
# 38342      offer      0  control          NaN               2019      NaN
# 49185      offer   1200  control          NaN               2019  manuell
# 49262      offer   2000     test          NaN               2018      NaN
# 8882       offer   5300  control          NaN               2018  manuell
#
# ...

# %% [markdown]
# ## Thank you for reading!!
